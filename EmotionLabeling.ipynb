# %%
#io와 pandas 모듈 import
import io
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#불러올 파일의 경로를 filename 변수에 저장
filename = '/content/drive/MyDrive/감정단어사전0603.xlsx'
#pandas read_csv로 불러오기
data = pd.read_excel(filename)

Happiness = data[data['감정범주'].str.contains('기쁨')]
Surprise = data[data['감정범주'].str.contains('놀람')]
Neutral = data[data['감정범주'].str.contains('중성')]
Fear = data[data['감정범주'].str.contains('공포')]
Disgust = data[data['감정범주'].str.contains('혐오')]
Anger = data[data['감정범주'].str.contains('분노')]
Sadness = data[data['감정범주'].str.contains('슬픔')]

print(Happiness)
print("")
print(Surprise)
print("")
print(Neutral)
print("")
print(Fear)
print("")
print(Disgust)
print("")
print(Anger)
print("")
print(Sadness)
print("")
# Out:
#      일련번호      단어 감정범주    빈도  감정정도M  감정정도STD
# 2       3    가뿐하다   기쁨  81.3   5.36     2.89
# 13     14  감개무량하다   기쁨  83.8   7.23     2.55
# 14     15    감격하다   기쁨  92.5   7.81     2.16
# 15     16    감동하다   기쁨  88.8   7.48     2.32
# 16     17    감미롭다   기쁨  77.5   6.03     2.63
# ..    ...     ...  ...   ...    ...      ...
# 421   422     흥겹다   기쁨  93.8   7.72     2.10
# 424   425  희희낙락하다   기쁨  95.0   7.14     2.40
# 425   426   히죽거리다   기쁨  83.8   5.61     2.75
# 426   427   히죽거리다   기쁨  83.8   5.61     2.75
# 427   428      히히   기쁨  95.0   5.76     2.87
#
# [84 rows x 6 columns]
#
#      일련번호      단어 감정범주    빈도  감정정도M  감정정도STD
# 23     24   갑작스럽다   놀람  90.0   7.54     2.16
# 38     39    경악하다   놀람  76.3   8.46     1.82
# 39     40    경이롭다   놀람  76.3   7.77     2.12
# 67     68   급작스럽다   놀람  93.8   7.31     2.17
# 68     69    기겁하다   놀람  75.0   7.63     2.13
# 70     71    기막히다   놀람  68.8   6.89     2.54
# 71     72    기묘하다   놀람  53.8   6.35     2.31
# ...
